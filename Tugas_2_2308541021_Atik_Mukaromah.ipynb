# %%
nama = "Atik"
tempat = 'Cilacap, '
tanggal_lahir = '31 Maret 2005'

print('Perkenalkan nama saya ' + nama + ' saya lahir di ' + tempat + tanggal_lahir)
# Out:
# Perkenalkan nama saya Atik saya lahir di Cilacap, 31 Maret 2005

# %%
alas_21 = float(input("Masukkan alas segitiga :"))
tinggi_21 = float(input("Masukkan tinggi segitiga :"))
luas_segitiga_21 = (0.5 * alas_21 * tinggi_21)
print("Luas segitiga adalah :" + str(luas_segitiga_21))
# Out:
# Masukkan alas segitiga : 12
# Masukkan tinggi segitiga : 2
# Luas segitiga adalah :12.0

# %%
lagu = 'Taylor Swift'

print(lagu[:])
print(lagu[0:1])
print(lagu[0:2])
print(lagu[0:3])
print(lagu[0:-1])
print(lagu[:-3])
print(lagu[1:])
# Out:
# Taylor Swift
# T
# Ta
# Tay
# Taylor Swif
# Taylor Sw
# aylor Swift

# %%
 novel = "Hujan, Tere Liye"
print(novel[0])
print(novel[2])
print(novel[-1])
print(novel[2:5])
print(novel[1:])
print(novel[:-1])
print(novel[2:-1:3])
# Out:
# H
# j
# e
# jan
# ujan, Tere Liye
# Hujan, Tere Liy
# j,e y

# %%
judul = 'Bunga Matahari sangat amat  cantik'
print(len(judul))
print('Bunga' in judul)
print('Mawar' in judul)
# Out:
# 34
# True
# False

# %%
judul.upper()
# Out:
# 'BUNGA MATAHARI SANGAT AMAT  CANTIK'

# %%
judul.lower()
# Out:
# 'bunga matahari sangat amat  cantik'

# %%
judul.find('matahari')
# Out:
# -1

# %%
judul.find('Bunga')
# Out:
# 0

# %%
judul.replace('Bunga', 'Pohon')
# Out:
# 'Pohon Matahari sangat amat  cantik'

# %%
judul.replace('matahari', 'Mawar')
# Out:
# 'Bunga Matahari sangat amat  cantik'

# %%
print(1000+1)
print(1000-1)
print(1000*1)
print(1000/3)
print(1000//3)
print(1000%3)
print(729**3)
# Out:
# 1001
# 999
# 1000
# 333.3333333333333
# 333
# 1
# 387420489

# %%
x=31
x+=1
print(x)
# Out:
# 32

# %%
x_21=31
x_21-=11
print(x_21)
# Out:
# 20

# %%
x_21=31
x_21*=5
print(x_21)
# Out:
# 155

# %%
x_21=10
x_21**=2
print(x_21)
# Out:
# 100

# %%
m_21 = 100>99
print(m_21)
m_21 = 7<1
print(m_21)
m_21 = 18 >= 20
print(m_21)
m_21 = 31 <= 35
print(m_21)
m_21 = 5 == 5
print(m_21)
m_21 = 10 == 11
print(m_21)
m_21 = 1 != 2
print(m_21)
# Out:
# True
# False
# False
# True
# True
# False
# True

# %%
sepatu_kakak_21 = 39
sepatu_adik_21 = 34
print(sepatu_kakak_21 > 34 and sepatu_adik_21 < 39)
# Out:
# True

# %%
print(sepatu_kakak_21 < 40 or sepatu_adik_21 < 29)
# Out:
# True

# %%
print(sepatu_kakak_21 > 40 or sepatu_adik_21 < 29)
# Out:
# False

# %%
print(not (sepatu_kakak_21 > 40 or sepatu_adik_21 < 29))
# Out:
# True

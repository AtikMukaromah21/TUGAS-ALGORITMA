# %%
import pandas as pd
print("Pengeluaran Hari Ini!!! ")
uang_di_bank_21 = input("Jumlah uang di bank :")
pengeluaran_21 = input("Jumlah pengeluaran hari ini : ")
uang_di_bank_21 = int(uang_di_bank_21)
pengeluaran_21 = int(pengeluaran_21)
if pengeluaran_21 >= 100000:
    print("Anda boros!") 
elif pengeluaran_21 <= 100000:
    print("Wow tetap berhemat ya!")
# Out:
# Pengeluaran Hari Ini!!!
# Jumlah uang di bank : 1000000
# Jumlah pengeluaran hari ini :  20000
# Wow tetap berhemat ya!

# %%
jari_jari_21 = float(input("Masukkan jari-jari lingkaran: "))
keliling_lingkaran_21 = 2 * 3.14 * jari_jari_21
luas_lingkaran_21 = 3.14 * (jari_jari_21 ** 2)
print("Keliling lingkaran adalah:",keliling_lingkaran_21)
print("Luas lingkaran adalah:",luas_lingkaran_21)
# Out:
# Masukkan jari-jari lingkaran:  4
# Keliling lingkaran adalah: 25.12
# Luas lingkaran adalah: 50.24

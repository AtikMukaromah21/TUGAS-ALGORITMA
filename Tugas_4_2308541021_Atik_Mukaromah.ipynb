# %%
sayuran = ['wortel', 'jagung', 'tomat', 'bayam', 'sawi', 'pakcoy']
print(sayuran)
# Out:
# ['wortel', 'jagung', 'tomat', 'bayam', 'sawi', 'pakcoy']

# %%
print(sayuran[-1])
print(sayuran[0])
print(sayuran[1])
print(sayuran[2])
print(sayuran[-3])
print(sayuran[-2])
# Out:
# pakcoy
# wortel
# jagung
# tomat
# bayam
# sawi

# %%
sayuran[-1] = 'terong'
print(sayuran)
# Out:
# ['wortel', 'jagung', 'tomat', 'bayam', 'sawi', 'terong']

# %%
print(sayuran[0:-2])
# Out:
# ['wortel', 'jagung', 'tomat', 'bayam']

# %%
# tidak merubah list
print(sayuran)
# Out:
# ['wortel', 'jagung', 'tomat', 'bayam', 'sawi', 'terong']

# %%
sayuran = input("Jenis sayuran yang kamu suka")
jenis_sayur = ['kol', 'wortel', 'kentang', 'sawi putih', 'daun bawang']
print("eummmm yummy, " + (sayuran) + " ini sangat enak" )
# Out:
# Jenis sayuran yang kamu suka wortel
# eummmm yummy, wortel ini sangat enak

# %%
sayuran = ['kol', 'wortel', 'kentang', 'sawi putih', 'daun bawang']
sayuran.append('jagung')
print(sayuran)
# Out:
# ['kol', 'wortel', 'kentang', 'sawi putih', 'daun bawang', 'jagung']

# %%
sayuran.insert(1, 'bayam')
print(sayuran)
# Out:
# ['kol', 'bayam', 'wortel', 'kentang', 'sawi putih', 'daun bawang', 'jagung']

# %%
sayuran.remove('bayam')
print(sayuran)
# Out:
# ['kol', 'wortel', 'kentang', 'sawi putih', 'daun bawang', 'jagung']

# %%
print('kangkung' in sayuran)
# Out:
# False

# %%
print('wortel' in sayuran)
# Out:
# True

# %%
print(len(sayuran))
# Out:
# 6

# %%
sayuran = ['kol', 'wortel', 'bayam', 'jagung', 'sawi']
for jenis in sayuran:
    print(jenis)
# Out:
# kol
# wortel
# bayam
# jagung
# sawi

# %%
sayur = 3
while sayur < len(sayuran):
    print("Sayuan kesukaan saya adalah " + sayuran[sayur])
    sayur += 1
# Out:
# Sayuan kesukaan saya adalah jagung
# Sayuan kesukaan saya adalah sawi
